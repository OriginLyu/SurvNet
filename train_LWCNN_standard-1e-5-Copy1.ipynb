# %% [markdown]
# <a href="https://colab.research.google.com/github/shalabh147/Brain-Tumor-Segmentation-and-Survival-Prediction-using-Deep-Neural-Networks/blob/master/surv_pred_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports
import pandas as pd
import os
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import csv as csv

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, concatenate, Flatten
from tensorflow.keras.layers import Conv2D, Dense, Activation, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Dropout, ReLU, LeakyReLU, BatchNormalization

from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers, initializers, optimizers
from tensorflow.keras.optimizers import Adam, SGD

import seaborn as sns
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix

# %%
path_project = '/home/origin/Research/'
path_clinical = path_project + 'Data/clinical/Pre-operative_TCGA-GBM/survival_info_all.csv'
path_MRI_training = path_project + 'Data/MRI/Pre-operative/Training/'
path_MRI_validation = path_project + 'Data/MRI/Pre-operative/Validation/'

IDs_patients = os.listdir(path_MRI_training) + os.listdir(path_MRI_validation)
IDs_patients.sort()
count_patients = len(IDs_patients)
age_dict = {}
OS_dict = {}
threshold = 360 # days
seg_label = 'GlistrBoost.nii'


def standardize(image):
  standardized_image = np.zeros(image.shape)
  # iterate over the `z` dimension
  for z in range(image.shape[2]):
    # get a slice of the image at channel c and z-th dimension `z`
    image_slice = image[:, :, z]
    # subtract the mean from image_slice
    centered = image_slice - np.mean(image_slice)
    # divide by the standard deviation (only if it is different from zero)
    if np.std(centered) != 0:
        centered = centered / np.std(centered)
    # update  the slice of standardized image with the scaled centered and scaled image
    standardized_image[:, :, z] = centered
    
  return standardized_image

# %%
dtypes = dict.fromkeys(pd.read_csv(path_clinical, encoding='gbk', nrows=1).columns.tolist(), str)
data_clinical = pd.read_csv(path_clinical, encoding='gbk', dtype=dtypes)

# produce the dict of age and overall survival
head_IDs, head_age, head_OS = list(dtypes.keys())[0], list(dtypes.keys())[1], list(dtypes.keys())[2]
cases_IDs = list(data_clinical[head_IDs])
cases_age = list(data_clinical[head_age].apply(pd.to_numeric, errors='coerce').fillna(0))
cases_OS = list(data_clinical[head_OS].apply(pd.to_numeric, errors='coerce').fillna(0))
age_dict = dict(zip(cases_IDs, cases_age))
OS_dict = dict(zip(cases_IDs, cases_OS))

# %%
# training set loading
training_set_all = os.listdir(path_MRI_training)
training_set = []
slice_loc_training = []

for IDs in training_set_all:
    if IDs in OS_dict.keys():
        training_set.append(IDs)
        
count_patients_training = len(training_set)
input_training = np.zeros((count_patients_training, 240, 240, 5))
age_training = np.zeros((count_patients_training, 1))
ground_truth_training = np.zeros((count_patients_training, 2))
cnt = 0
for image_num in range(count_patients_training):
    x = training_set[image_num]
    folder_path = path_MRI_training + x
    modalities = os.listdir(folder_path)
    modalities.sort()

    data = np.zeros((240, 240, 155, 4))
    image_data2 = np.zeros((240, 240, 155))
    w = 0
    for j in range(len(modalities)):
        image_path = folder_path + '/' + modalities[j]
        if not (image_path.find(seg_label) == -1):
            img = nib.load(image_path)
            image_data2 = img.get_fdata()
            image_data2 = np.asarray(image_data2)
            image_data2 = standardize(image_data2)
        else:
            img = nib.load(image_path)
            image_data = img.get_fdata()
            image_data = np.asarray(image_data)
            image_data = standardize(image_data)
            data[:, :, :, w] = image_data
            w = w + 1

    image_data2[image_data2 == 4] = 3
    slice_nonzero = []
    width, height, queue = image_data2.shape
    for i in range(0, queue, 10):
        image_array = image_data2[:, :, i]
        slice_nonzero.append(np.count_nonzero(image_array))
    slice_nonzero_array = np.array(slice_nonzero)
    slice_loc_training.append(slice_nonzero_array.argmax() * 10)

    input_training[cnt, :, :, :4] = data[:, :, slice_loc_training[image_num], :]
    input_training[cnt, :, :, 4] = image_data2[:, :, slice_loc_training[image_num]]
    age_training[cnt, 0] = float(age_dict[x])
    OS_training = int(OS_dict[x])

    if int(OS_training) < threshold:
        ground_truth_training[cnt, 0] = 1
    else:
        ground_truth_training[cnt, 1] = 1
    cnt += 1
    
print('training set: ', len(input_training))
# Out:
# training set:  104

# %%
# validation set loading
validation_set = os.listdir(path_MRI_validation)
count_patients_val = len(validation_set)
slice_loc_val = []

input_val = np.zeros((count_patients_val, 240, 240, 5))
age_val = np.zeros((count_patients_val, 1))
ground_truth_val = np.zeros((count_patients_val, 2))
cnt = 0
for image_num in range(count_patients_val):
    x = validation_set[image_num]
    folder_path = path_MRI_validation + x
    modalities = os.listdir(folder_path)
    modalities.sort()

    data = np.zeros((240, 240, 155, 4))
    image_data2 = np.zeros((240, 240, 155))
    w = 0
    for j in range(len(modalities)):
        image_path = folder_path + '/' + modalities[j]
        if not (image_path.find(seg_label) == -1):
            img = nib.load(image_path)
            image_data2 = img.get_fdata()
            image_data2 = np.asarray(image_data2)
            image_data2 = standardize(image_data2)
        else:
            img = nib.load(image_path)
            image_data = img.get_fdata()
            image_data = np.asarray(image_data)
            image_data = standardize(image_data)
            data[:, :, :, w] = image_data
            w = w + 1

    image_data2[image_data2 == 4] = 3
    slice_nonzero = []
    width, height, queue = image_data2.shape
    for i in range(0, queue, 10):
        image_array = image_data2[:, :, i] 
        slice_nonzero.append(np.count_nonzero(image_array))
    slice_nonzero_array = np.array(slice_nonzero)
    slice_loc_val.append(slice_nonzero_array.argmax() * 10)

    input_val[cnt, :, :, :4] = data[:, :, slice_loc_val[image_num], :]
    input_val[cnt, :, :, 4] = image_data2[:, :, slice_loc_val[image_num]]
    age_val[cnt, 0] = float(age_dict[x])
    OS_val = int(OS_dict[x])

    if int(OS_val) < threshold:
        ground_truth_val[cnt, 0] = 1
    else:
        ground_truth_val[cnt, 1] = 1
    cnt += 1
    
print('validation set: ', len(input_val))
# Out:
# validation set:  17

# %%
cnt = 0
for patients_num in range(count_patients):
  image1 = IDs_patients[patients_num]
  if image1 in OS_dict:
    cnt += 1
print('the number of patients who have age and OS information: ', cnt)

print('the slices of 3D scans in training set are: ', slice_loc_training)
print('the slices of 3D scans in validation set are: ', slice_loc_val)
# Out:
# the number of patients who have age and OS information:  121
# the slices of 3D scans in training set are:  [50, 50, 60, 40, 70, 50, 60, 30, 40, 70, 50, 30, 40, 40, 70, 50, 60, 30, 60, 30, 60, 70, 70, 30, 40, 90, 40, 40, 80, 30, 60, 40, 90, 60, 50, 60, 30, 40, 40, 60, 40, 30, 30, 30, 70, 30, 90, 40, 30, 30, 50, 40, 40, 30, 30, 30, 30, 30, 30, 30, 50, 40, 40, 50, 60, 50, 50, 40, 60, 60, 40, 20, 30, 80, 40, 40, 80, 30, 30, 30, 50, 60, 60, 40, 60, 40, 60, 60, 40, 60, 30, 70, 80, 40, 70, 40, 50, 60, 60, 40, 50, 40, 70, 70]
# the slices of 3D scans in validation set are:  [40, 40, 40, 40, 40, 30, 90, 50, 70, 70, 80, 40, 50, 50, 40, 40, 60]

# %%
def SurvPredNet(input_img,age_m):
    
    model = Sequential()
    
#     a1 = Conv2D(16,kernel_size = (3,3) , padding='same')(input_img)
#     a1 = Activation('relu')(a1)
#     a1 = Conv2D(16,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
#     a1 = Conv2D(24,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = Conv2D(24,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
#     a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
#     a1 = Conv2D(64,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = Conv2D(64,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = Conv2D(64,kernel_size = (3,3) , padding='same')(a1)
#     a1 = Activation('relu')(a1)
#     a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(input_img)
    a1 = Activation('relu')(a1)
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = Activation('relu')(a1)
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = Activation('relu')(a1)
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Flatten()(a1)
    a1 = concatenate([a1,age_m])
    
    a1 = Dense(32,activation = 'relu')(a1)
    a1 = Dense(16,activation = 'relu')(a1)
    outputs = Dense(2,activation = 'softmax')(a1)
    
    model = Model(inputs = [input_img,age_m] , outputs = outputs)
    return model

# saveModel = path_project + 'Thesis/Experiments_Record/my_code/20220815/1/Model/'
# checkpoint = callbacks.ModelCheckpoint(saveModel+'weights.{epoch:02d}.h5', monitor='val_accuracy', verbose=0,
#                                 save_best_only=True,
#                                 save_weights_only=False, mode='max')

# %%
lr = 1e-5
decay_rate = 2e-7
input_img = Input((240,240,5))
age_m = Input(1)
model = SurvPredNet(input_img,age_m)

# accu_metric = 'categorical_accuracy'
accu_metric = 'accuracy'
sgd = optimizers.SGD(learning_rate=lr, decay=decay_rate, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=accu_metric)
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=accu_metric)
# model.compile(loss='categorical_crossentropy',
#              optimizer=tf.keras.optimizers.SGD(learning_rate =0.0001),
#              metrics=[tf.keras.metrics.AUC()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 240, 240, 5  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 240, 240, 32  1472        ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 240, 240, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 240, 240, 32  9248        ['activation[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 240, 240, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 240, 240, 32  9248        ['activation_1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 240, 240, 32  0           ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 120, 120, 32  0           ['activation_2[0][0]']
#                                 )
#
#  flatten (Flatten)              (None, 460800)       0           ['max_pooling2d[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 460801)       0           ['flatten[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense (Dense)                  (None, 32)           14745664    ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 16)           528         ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 2)            34          ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 14,766,194
# Trainable params: 14,766,194
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2022-08-25 13:20:14.076441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.115020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.115158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.116006: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-25 13:20:14.116560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.116672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.116743: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.587903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.588031: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.588111: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-25 13:20:14.589141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3489 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
epoch=200
bz=16
history = model.fit(x=[input_training, age_training], y=ground_truth_training, epochs=epoch, batch_size=bz, 
                    validation_data=[[input_val, age_val], ground_truth_val])
# history = model.fit(x=[input_training, age_training], y=ground_truth_training, epochs=epoch, batch_size=bz, 
#                     validation_data=[[input_val, age_val], ground_truth_val], 
#                     callbacks=checkpoint)
# Out:
# Epoch 1/200
# 2022-08-25 13:20:19.391325: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-08-25 13:20:20.516817: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-08-25 13:20:20.681951: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 7/7 [==============================] - 4s 115ms/step - loss: 0.7111 - accuracy: 0.5192 - val_loss: 0.7097 - val_accuracy: 0.4706
# Epoch 2/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.7001 - accuracy: 0.4712 - val_loss: 0.6909 - val_accuracy: 0.5294
# Epoch 3/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6855 - accuracy: 0.5865 - val_loss: 0.6884 - val_accuracy: 0.5882
# Epoch 4/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6815 - accuracy: 0.5481 - val_loss: 0.6923 - val_accuracy: 0.4706
# Epoch 5/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.6734 - accuracy: 0.5385 - val_loss: 0.6937 - val_accuracy: 0.3529
# Epoch 6/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6691 - accuracy: 0.5481 - val_loss: 0.6894 - val_accuracy: 0.5882
# Epoch 7/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.6614 - accuracy: 0.6346 - val_loss: 0.6834 - val_accuracy: 0.5294
# Epoch 8/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.6566 - accuracy: 0.6923 - val_loss: 0.6812 - val_accuracy: 0.6471
# Epoch 9/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6499 - accuracy: 0.7019 - val_loss: 0.6812 - val_accuracy: 0.6471
# Epoch 10/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.6444 - accuracy: 0.7019 - val_loss: 0.6782 - val_accuracy: 0.7059
# Epoch 11/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.6375 - accuracy: 0.7019 - val_loss: 0.6742 - val_accuracy: 0.7059
# Epoch 12/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.6324 - accuracy: 0.7692 - val_loss: 0.6756 - val_accuracy: 0.5882
# Epoch 13/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.6264 - accuracy: 0.7596 - val_loss: 0.6738 - val_accuracy: 0.7059
# Epoch 14/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6207 - accuracy: 0.7692 - val_loss: 0.6705 - val_accuracy: 0.6471
# Epoch 15/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.6175 - accuracy: 0.7404 - val_loss: 0.6680 - val_accuracy: 0.7059
# Epoch 16/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6103 - accuracy: 0.7981 - val_loss: 0.6672 - val_accuracy: 0.7059
# Epoch 17/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0
200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2075 - accuracy: 1.0000 - val_loss: 0.5223 - val_accuracy: 0.7647
# Epoch 110/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2046 - accuracy: 1.0000 - val_loss: 0.5215 - val_accuracy: 0.7647
# Epoch 111/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2017 - accuracy: 1.0000 - val_loss: 0.5234 - val_accuracy: 0.7647
# Epoch 112/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1996 - accuracy: 1.0000 - val_loss: 0.5214 - val_accuracy: 0.7647
# Epoch 113/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1973 - accuracy: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.7647
# Epoch 114/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1952 - accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.7647
# Epoch 115/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1935 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.7647
# Epoch 116/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1902 - accuracy: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.7647
# Epoch 117/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1880 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.7647
# Epoch 118/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1860 - accuracy: 1.0000 - val_loss: 0.5202 - val_accuracy: 0.7647
# Epoch 119/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1843 - accuracy: 1.0000 - val_loss: 0.5182 - val_accuracy: 0.7647
# Epoch 120/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1816 - accuracy: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.7647
# Epoch 121/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1790 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.7647
# Epoch 122/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1779 - accuracy: 1.0000 - val_loss: 0.5160 - val_accuracy: 0.7647
# Epoch 123/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1755 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.7647
# Epoch 124/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1732 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.7647
# Epoch 125/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1715 - accuracy: 1.0000 - val_loss: 0.5119 - val_accuracy: 0.7647
# Epoch 126/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1693 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.7647
# Epoch 127/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1675 - accuracy: 1.0000 - val_loss: 0.5089 - val_accuracy: 0.7647
# Epoch 128/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1662 - accuracy: 1.0000 - val_loss: 0.5113 - val_accuracy: 0.7647
# Epoch 129/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1638 - accuracy: 1.0000 - val_loss: 0.5117 - val_accuracy: 0.7647
# Epoch 130/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1618 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.7647
# Epoch 131/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1601 - accuracy: 1.0000 - val_loss: 0.5105 - val_accuracy: 0.7647
# Epoch 132/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1580 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.7647
# Epoch 133/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1566 - accuracy: 1.0000 - val_loss: 0.5092 - val_accuracy: 0.7647
# Epoch 134/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1544 - accuracy: 1.0000 - val_loss: 0.5092 - val_accuracy: 0.7647
# Epoch 135/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1533 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 0.7647
# Epoch 136/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1509 - accuracy: 1.0000 - val_loss: 0.5087 - val_accuracy: 0.7647
# Epoch 137/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1492 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.7647
# Epoch 138/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1480 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.7647
# Epoch 139/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1472 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.7647
# Epoch 140/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1455 - accuracy: 1.0000 - val_loss: 0.5035 - val_accuracy: 0.7647
# Epoch 141/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1436 - accuracy: 1.0000 - val_loss: 0.5073 - val_accuracy: 0.7647
# Epoch 142/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1414 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.7647
# Epoch 143/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1399 - accuracy: 1.0000 - val_loss: 0.5044 - val_accuracy: 0.7647
# Epoch 144/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1379 - accuracy: 1.0000 - val_loss: 0.5069 - val_accuracy: 0.7647
# Epoch 145/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1368 - accuracy: 1.0000 - val_loss: 0.5068 - val_accuracy: 0.7647
# Epoch 146/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1354 - accuracy: 1.0000 - val_loss: 0.5031 - val_accuracy: 0.7647
# Epoch 147/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1341 - accuracy: 1.0000 - val_loss: 0.5017 - val_accuracy: 0.7647
# Epoch 148/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1323 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.7647
# Epoch 149/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1305 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.7647
# Epoch 150/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1300 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.7647
# Epoch 151/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1297 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.7647
# Epoch 152/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1275 - accuracy: 1.0000 - val_loss: 0.5048 - val_accuracy: 0.7647
# Epoch 153/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1250 - accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.7647
# Epoch 154/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1238 - accuracy: 1.0000 - val_loss: 0.5050 - val_accuracy: 0.7647
# Epoch 155/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1226 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.7647
# Epoch 156/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1234 - accuracy: 1.0000 - val_loss: 0.4979 - val_accuracy: 0.7647
# Epoch 157/200
# 7/7 [==============================] - 0s 50ms/step - loss: 0.1199 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.7647
# Epoch 158/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1181 - accuracy: 1.0000 - val_loss: 0.4995 - val_accuracy: 0.7647
# Epoch 159/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1176 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.7647
# Epoch 160/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1156 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.7647
# Epoch 161/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1145 - accuracy: 1.0000 - val_loss: 0.5022 - val_accuracy: 0.7647
# Epoch 162/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1132 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.7647
# Epoch 163/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1119 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.7647
# Epoch 164/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1114 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.7647
# Epoch 165/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1099 - accuracy: 1.0000 - val_loss: 0.5029 - val_accuracy: 0.7647
# Epoch 166/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1091 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.7647
# Epoch 167/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1074 - accuracy: 1.0000 - val_loss: 0.5022 - val_accuracy: 0.7647
# Epoch 168/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1062 - accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.7647
# Epoch 169/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1052 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.7647
# Epoch 170/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1040 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.7647
# Epoch 171/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.7647
# Epoch 172/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.1017 - accuracy: 1.0000 - val_loss: 0.4981 - val_accuracy: 0.7647
# Epoch 173/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.1007 - accuracy: 1.0000 - val_loss: 0.4989 - val_accuracy: 0.7647
# Epoch 174/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0996 - accuracy: 1.0000 - val_loss: 0.4981 - val_accuracy: 0.7647
# Epoch 175/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0990 - accuracy: 1.0000 - val_loss: 0.5007 - val_accuracy: 0.7647
# Epoch 176/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0977 - accuracy: 1.0000 - val_loss: 0.4984 - val_accuracy: 0.7647
# Epoch 177/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0966 - accuracy: 1.0000 - val_loss: 0.4980 - val_accuracy: 0.7647
# Epoch 178/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0956 - accuracy: 1.0000 - val_loss: 0.5013 - val_accuracy: 0.7647
# Epoch 179/200
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0951 - accuracy: 1.0000 - val_loss: 0.5017 - val_accuracy: 0.7647
# Epoch 180/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0943 - accuracy: 1.0000 - val_loss: 0.5043 - val_accuracy: 0.7647
# Epoch 181/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.7647
# Epoch 182/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0920 - accuracy: 1.0000 - val_loss: 0.5007 - val_accuracy: 0.7647
# Epoch 183/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0913 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.7647
# Epoch 184/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0901 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.7647
# Epoch 185/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0893 - accuracy: 1.0000 - val_loss: 0.5027 - val_accuracy: 0.7647
# Epoch 186/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0890 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.7647
# Epoch 187/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 0.5049 - val_accuracy: 0.7647
# Epoch 188/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0869 - accuracy: 1.0000 - val_loss: 0.5029 - val_accuracy: 0.7647
# Epoch 189/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0861 - accuracy: 1.0000 - val_loss: 0.5023 - val_accuracy: 0.7647
# Epoch 190/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0850 - accuracy: 1.0000 - val_loss: 0.5052 - val_accuracy: 0.7647
# Epoch 191/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0843 - accuracy: 1.0000 - val_loss: 0.5057 - val_accuracy: 0.7647
# Epoch 192/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0834 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.7647
# Epoch 193/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 0.5031 - val_accuracy: 0.7647
# Epoch 194/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.7647
# Epoch 195/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0809 - accuracy: 1.0000 - val_loss: 0.5062 - val_accuracy: 0.7647
# Epoch 196/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0801 - accuracy: 1.0000 - val_loss: 0.5047 - val_accuracy: 0.7647
# Epoch 197/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0800 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.7647
# Epoch 198/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0786 - accuracy: 1.0000 - val_loss: 0.5095 - val_accuracy: 0.7647
# Epoch 199/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 0.5061 - val_accuracy: 0.7647
# Epoch 200/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 0.5061 - val_accuracy: 0.7647

# %%
######################################## change the save path here ########################################
savepath = path_project + 'Thesis/Experiments_Record/my_code/all_modalities/1e-5/2/'
######################################## change the save path here ########################################

import pickle
with open(savepath + 'log_history.txt', 'wb') as file_txt:
    pickle.dump(history.history, file_txt)
    
model.save(savepath + 'LW_CNN.h5')

# %%
plt.rcParams["axes.grid"] = False
plt.plot(history.history['loss'], color='blue', label='training loss')
plt.plot(history.history[accu_metric], color='red', label='training accuracy')
plt.ylim(0, max(max(history.history['loss'])+0.4, max(history.history[accu_metric])+0.4))
plt.legend()
plt.title('Training Curve')
plt.ylabel('Loss')
plt.xlabel('epochs')
s = savepath + 'epochwise_training.pdf'
plt.savefig(s)
plt.show()
plt.close()

plt.rcParams["axes.grid"] = False
plt.plot(history.history['val_loss'], color='blue', label='validation loss')
plt.plot(history.history['val_' + accu_metric], color='red', label='validation accuracy')
plt.ylim(0,max(max(history.history['val_loss'])+0.4, max(history.history['val_' + accu_metric])+0.4))
plt.legend(bbox_to_anchor=(1,1))
plt.title('Validation Curve')
plt.ylabel('Accuracy')
plt.xlabel('epochs')
s = savepath + 'epochwise_validation.pdf'
plt.savefig(s)
plt.show()
plt.close()

# %%
plt.rcParams["axes.grid"] = False
plt.plot(history.history['loss'], color='blue', label='training loss')
plt.plot(history.history['val_loss'], color='red', label='validation loss')
plt.ylim(0, max(max(history.history['loss'])+0.2, max(history.history['val_loss'])+0.2))
plt.legend()
plt.title('Loss vs epochs')
plt.ylabel('Loss')
plt.xlabel('epochs')
s = savepath + 'epochwise_loss.pdf'
plt.savefig(s)
plt.show()
plt.close()

plt.rcParams["axes.grid"] = False
plt.plot(history.history[accu_metric], color='blue', label='training accuracy')
plt.plot(history.history['val_' + accu_metric], color='red', label='validation accuracy')
plt.ylim(0,max(max(history.history[accu_metric])+0.4, max(history.history['val_' + accu_metric])+0.4))
plt.legend(bbox_to_anchor=(1,1))
plt.title('Accuracy vs epochs')
plt.ylabel('Accuracy')
plt.xlabel('epochs')
s = savepath + 'epochwise_accuracy.pdf'
plt.savefig(s)
plt.show()
plt.close()

# %%
# confusion matrix on validation set
y_pred = model.predict(x=[input_val, age_val])
y_true = ground_truth_val
labels = ['Short', 'Long']

sns.set()
f,ax=plt.subplots()
C2= confusion_matrix(y_true.argmax(axis=1), y_pred.argmax(axis=1))

print(C2)
sns.heatmap(C2,annot=True,ax=ax)
xlocations = np.array(range(len(labels)))+0.5
plt.xticks(xlocations, labels)
plt.yticks(xlocations, labels)
ax.set_title('confusion matrix')
ax.set_xlabel('Predict')
ax.set_ylabel('True')

print('accuracy on validation set: ', (C2[0][0]+C2[1][1])/(C2[0][0]+C2[1][1]+C2[0][1]+C2[1][0]))

plt.savefig(savepath + 'confusion_matrix_val.pdf')

# pd.crosstab(y_true.argmax(axis=1), y_pred.argmax(axis=1), rownames=['label'], colnames=['predict'])
# Out:
# [[7 1]
#  [3 6]]
# accuracy on validation set:  0.7647058823529411

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score,accuracy_score

# # prediction on training set
# y_predict = model.predict([input_training, age], verbose=1)
# # y_predict = (y_predict > 0.007).astype(int)
# y_predict = (y_predict > 0.01).astype(int)
# y_true = np.reshape(ground_truth, [-1])
# y_pred = np.reshape(y_predict, [-1])
y_pred = model.predict([input_training, age_training], verbose=1)
y_pred = y_pred.argmax(axis=1)
y_true = ground_truth_training
y_true = y_true.argmax(axis=1)

# evalution index
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred, average='binary')
f1score = f1_score(y_true, y_pred, average='binary')
# Micro F1: 将n分类的评价拆成n个二分类的评价，将n个二分类评价的TP、FP、RN对应相加，计算评价准确率和召回率，由这2个准确率和召回率计算的F1 score即为Micro F1。
# Macro F1: 将n分类的评价拆成n个二分类的评价，计算每个二分类的F1 score，n个F1 score的平均值即为Macro F1。
# 一般来讲，Macro F1、Micro F1高的分类效果好。Macro F1受样本数量少的类别影响大。
micro_f1 = f1_score(y_true, y_pred,average='micro')
macro_f1 = f1_score(y_true, y_pred,average='macro')

print('accuracy:',accuracy)
print('precision:',precision)
print('recall:',recall)
print('f1score:',f1score)
print('Macro-F1: {}'.format(macro_f1))
print('Micro-F1: {}'.format(micro_f1))

# prediction on validation set
print('\n\n')
# y_predict_val = model.predict([input_to_val, age_val], verbose=1)
# y_predict_val = (y_predict_val > 0.01).astype(int)
# y_true_val = np.reshape(ground_truth_val, [-1])
# y_pred_val = np.reshape(y_predict_val, [-1])
y_pred_val = model.predict([input_val, age_val], verbose=1)
y_pred_val = y_pred_val.argmax(axis=1)
y_true_val = ground_truth_val
y_true_val = y_true_val.argmax(axis=1)

# evalution index
accuracy_val = accuracy_score(y_true_val, y_pred_val)
precision_val = precision_score(y_true_val, y_pred_val)
recall_val = recall_score(y_true_val, y_pred_val, average='binary')
f1score_val = f1_score(y_true_val, y_pred_val, average='binary')
micro_f1_val = f1_score(y_true_val, y_pred_val,average='micro')
macro_f1_val = f1_score(y_true_val, y_pred_val,average='macro')

print('accuracy_val:',accuracy_val)
print('precision_val:',precision_val)
print('recall_val:',recall_val)
print('f1score_val:',f1score_val)
print('Macro-F1_val: {}'.format(macro_f1_val))
print('Micro-F1_val: {}'.format(micro_f1_val))
# Out:
# 4/4 [==============================] - 0s 26ms/step
# accuracy: 1.0
# precision: 1.0
# recall: 1.0
# f1score: 1.0
# Macro-F1: 1.0
# Micro-F1: 1.0
#
#
#
# 1/1 [==============================] - 0s 15ms/step
# accuracy_val: 0.7647058823529411
# precision_val: 0.8571428571428571
# recall_val: 0.6666666666666666
# f1score_val: 0.75
# Macro-F1_val: 0.7638888888888888
# Micro-F1_val: 0.7647058823529412

# %%
############################### save the hyperparameters and metrics ###############################

with open(savepath + 'log.txt','w',encoding='utf-8') as f:
    f.write('######################################\n')
    f.write('optimizer: ' + 'sgd' + '\n')
    f.write('learning rate: ' + str(lr) + '\n')
    f.write('decay rate: ' + str(decay_rate) + '\n')
    f.write('epochs: ' + str(epoch) + '\n')
    f.write('batch size: ' + str(bz) + '\n')
    
    f.write('\n\n######################################\n')
    f.write('accuracy: ' + str(accuracy_val) + '\n')
    f.write('precision: ' + str(precision_val) + '\n')
    f.write('recall: ' + str(recall_val) + '\n')
    f.write('f1score: ' + str(f1score_val) + '\n')
    
    f.write('\n\n######################################\n')
    model.summary(print_fn=lambda x: f.write(x + '\n'))
